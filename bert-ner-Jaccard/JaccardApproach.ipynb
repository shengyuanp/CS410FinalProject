# %%
import pandas as pd
import json

# read in scraped mayo symptoms
with open("mayo_data.json", 'r') as j:
     data = json.loads(j.read())

symptoms=[]
specialties=[]
diseases=[]

for disease in list(data.keys()):
    list_of_symptoms=data[disease]['symptoms']
    if len(list_of_symptoms)==0:
        pass
    symptoms.append(list_of_symptoms)
    diseases.append([disease]*len(list_of_symptoms))
    list_of_specialties=data[disease]['specialties']
    specialtystr=','.join(list_of_specialties)
    specialties.append([specialtystr]*len(list_of_symptoms))

def flatten(l):
    return [item for sublist in l for item in sublist]

diseases=flatten(diseases)
symptoms=flatten(symptoms)
specialties=flatten(specialties)

lst = [diseases,symptoms,specialties]
df = pd.DataFrame(
    {'disease': diseases,
     'symptoms': symptoms,
     'specialties': specialties
    })

# %%
input_value = df.groupby('disease', as_index=False).agg(lambda x: ' '.join(x.unique()))
# df['symptoms'] = df['symptoms'].str.split()
input_value
# Out:
#                            disease  \
# 0                       ACL injury
# 1                             ARDS
# 2        Abdominal aortic aneurysm
# 3                        Achalasia
# 4              Achilles tendinitis
# ..                             ...
# 531                     Vulvodynia
# 532  Waldenstrom macroglobulinemia
# 533       Wet macular degeneration
# 534                   Wilms' tumor
# 535      Yeast infection (vaginal)
#
#                                               symptoms  \
# 0    Rapid swelling A loud pop or a "popping" sensa...
# 1    Severe shortness of breath Labored and unusual...
# 2    Back pain Deep, constant pain in the belly are...
# 3    Inability to swallow (dysphagia), which may fe...
# 4    Achilles tendinitis Achilles tendinitis is an ...
# ..                                                 ...
# 531  Rawness Vulva Burning Painful intercourse (dys...
# 532  Easy bruising Fever Shortness of breath Bleedi...
# 533  Decreased intensity or brightness of colors In...
# 534  Fever Shortness of breath An abdominal mass yo...
# 535  Itching and irritation in the vagina and vulva...
#
#                                            specialties
# 0    Physical Medicine and Rehabilitation,Sports Me...
# 1    Pulmonary Medicine,Critical Care,Extracorporea...
# 2    Vascular centers,Vascular and Endovascular Sur...
# 3    Pediatric Surgery,Gastroenterology and Hepatol...
# 4    Physical Medicine and Rehabilitation,Sports Me...
# ..                                                 ...
# 531  Physical Medicine and Rehabilitation,Obstetric...
# 532  Transplant Center,Hematology,Bone Marrow Trans...
# 533                                      Ophthalmology
# 534  Pediatric Hematology/Oncology in Minnesota,Chi...
# 535                          Obstetrics and Gynecology
#
# [536 rows x 3 columns]

# %%
file = open("UserInputSymptoms.plk",'rb')
output = pd.read_pickle(file)
output
# Out:
#                               disease  \
# 0                   Aortic dissection
# 1             Chronic daily headaches
# 2                  Nephrotic syndrome
# 3                           Dizziness
# 4                           Emphysema
# ..                                ...
# 531  Pancreatic neuroendocrine tumors
# 532                      Hearing loss
# 533                    Retinoblastoma
# 534               Rumination syndrome
# 535                      Bell's palsy
#
#                                              userquery
# 0    \n-sudden and severe chest pain, often describ...
# 1    \nThere is no definitive answer to this questi...
# 2    \n-Fluid retention (edema)\n-Weight gain\n-Foa...
# 3    \nThe symptoms of dizziness can vary depending...
# 4    \nThe main symptom of emphysema is shortness o...
# ..                                                 ...
# 531  \nThe most common symptom of a pancreatic neur...
# 532  \nSome symptoms of hearing loss include strugg...
# 533  \n-One or both eyes may look enlarged\n-White ...
# 534  \nThere is no one definitive symptom of rumina...
# 535  \nThe symptoms of Bell's palsy include weaknes...
#
# [536 rows x 2 columns]

# %%
output['type'] = 'userquery'
input_value['type'] = 'system'
output = output.rename(columns={'userquery': 'symptoms'})
result = pd.concat([input_value, output], axis=0, join='inner')
display(result)
# Out:
#                               disease  \
# 0                          ACL injury
# 1                                ARDS
# 2           Abdominal aortic aneurysm
# 3                           Achalasia
# 4                 Achilles tendinitis
# ..                                ...
# 531  Pancreatic neuroendocrine tumors
# 532                      Hearing loss
# 533                    Retinoblastoma
# 534               Rumination syndrome
# 535                      Bell's palsy
#
#                                               symptoms       type
# 0    Rapid swelling A loud pop or a "popping" sensa...     system
# 1    Severe shortness of breath Labored and unusual...     system
# 2    Back pain Deep, constant pain in the belly are...     system
# 3    Inability to swallow (dysphagia), which may fe...     system
# 4    Achilles tendinitis Achilles tendinitis is an ...     system
# ..                                                 ...        ...
# 531  \nThe most common symptom of a pancreatic neur...  userquery
# 532  \nSome symptoms of hearing loss include strugg...  userquery
# 533  \n-One or both eyes may look enlarged\n-White ...  userquery
# 534  \nThere is no one definitive symptom of rumina...  userquery
# 535  \nThe symptoms of Bell's palsy include weaknes...  userquery
#
# [1072 rows x 3 columns]

# %%
result = result.replace('\n|-','', regex=True)
result['symptoms'] = result['symptoms'].str.split()
result
# Out:
#                               disease  \
# 0                          ACL injury
# 1                                ARDS
# 2           Abdominal aortic aneurysm
# 3                           Achalasia
# 4                 Achilles tendinitis
# ..                                ...
# 531  Pancreatic neuroendocrine tumors
# 532                      Hearing loss
# 533                    Retinoblastoma
# 534               Rumination syndrome
# 535                      Bell's palsy
#
#                                               symptoms       type
# 0    [Rapid, swelling, A, loud, pop, or, a, "poppin...     system
# 1    [Severe, shortness, of, breath, Labored, and, ...     system
# 2    [Back, pain, Deep,, constant, pain, in, the, b...     system
# 3    [Inability, to, swallow, (dysphagia),, which, ...     system
# 4    [Achilles, tendinitis, Achilles, tendinitis, i...     system
# ..                                                 ...        ...
# 531  [The, most, common, symptom, of, a, pancreatic...  userquery
# 532  [Some, symptoms, of, hearing, loss, include, s...  userquery
# 533  [One, or, both, eyes, may, look, enlargedWhite...  userquery
# 534  [There, is, no, one, definitive, symptom, of, ...  userquery
# 535  [The, symptoms, of, Bell's, palsy, include, we...  userquery
#
# [1072 rows x 3 columns]

# %%
import itertools

## Jaccard similarity functions obtained from https://stackoverflow.com/questions/71635040/get-jaccard-similarity-by-comparing-all-rows-in-a-pandas-dataframe-while-keeping
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(result["symptoms"], result["disease"], result["type"]))

result = []

for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"disease1": item[0][1], "disease2": item[1][1], "disease1_type": item[0][2], "disease2_type": item[1][2], "similarity": similarity}
    result.append(data)

result = pd.DataFrame(result)
result
# Out:
#                    disease1                   disease2 disease1_type  \
# 0                ACL injury                       ARDS        system
# 1                ACL injury  Abdominal aortic aneurysm        system
# 2                ACL injury                  Achalasia        system
# 3                ACL injury        Achilles tendinitis        system
# 4                ACL injury    Achilles tendon rupture        system
# ...                     ...                        ...           ...
# 574051         Hearing loss        Rumination syndrome     userquery
# 574052         Hearing loss               Bell's palsy     userquery
# 574053       Retinoblastoma        Rumination syndrome     userquery
# 574054       Retinoblastoma               Bell's palsy     userquery
# 574055  Rumination syndrome               Bell's palsy     userquery
#
#        disease2_type  similarity
# 0             system    0.071429
# 1             system    0.150000
# 2             system    0.112903
# 3             system    0.054545
# 4             system    0.172414
# ...              ...         ...
# 574051     userquery    0.063492
# 574052     userquery    0.142857
# 574053     userquery    0.042553
# 574054     userquery    0.069767
# 574055     userquery    0.053571
#
# [574056 rows x 5 columns]

# %%
result = result[result['disease1_type'] != result['disease2_type']]
result = result.sort_values("similarity", ascending=False)
result = result.drop_duplicates(subset=["disease2"], keep="first")
result[result['disease1'] == result['disease2']]
# Out:
#                        disease1                 disease2 disease1_type  \
# 96874                   Bunions                  Bunions        system
# 407381        Testicular cancer        Testicular cancer        system
# 281745                   Iritis                   Iritis        system
# 414405           Trigger finger           Trigger finger        system
# 421286         Uterine fibroids         Uterine fibroids        system
# ...                         ...                      ...           ...
# 22261      Alcohol use disorder     Alcohol use disorder        system
# 406783         Tension headache         Tension headache        system
# 335999  Obstructive sleep apnea  Obstructive sleep apnea        system
# 227022               Gingivitis               Gingivitis        system
# 351229              Pet allergy              Pet allergy        system
#
#        disease2_type  similarity
# 96874      userquery    0.500000
# 407381     userquery    0.395833
# 281745     userquery    0.388889
# 414405     userquery    0.345455
# 421286     userquery    0.307692
# ...              ...         ...
# 22261      userquery    0.123153
# 406783     userquery    0.120000
# 335999     userquery    0.119403
# 227022     userquery    0.115385
# 351229     userquery    0.092308
#
# [69 rows x 5 columns]

# %% [markdown]
# > Comment: Got 69 right out of the 536 inputs, about 12.87% accuracy.

# %% [markdown]
# ## Simple Test on Jaccard Similarity

# %%
def Convert(string):
    li = list(string.split(" "))
    return li

## symptoms from aortic dissection disease
str1 = "Sudden severe chest or upper back pain, often described as a tearing or ripping sensation, that spreads to the neck or down the back \
Sudden severe stomach pain Loss of consciousness Shortness of breath Symptoms similar to those of a stroke, including sudden vision problems, difficulty speaking, and weakness or loss of movement (paralysis) on one side of your body \
Weak pulse in one arm or thigh compared with the other Leg pain Difficulty walking"

## sample user input 
str2 = "I have shortness of breath, leg pain, loss of consciousness"
list1 = Convert(str1)
list2 = Convert(str2)

def jaccard_similarity(list1, list2):
    intersection = len(list(set(list1).intersection(list2)))
    union = (len(set(list1)) + len(set(list2))) - intersection
    return float(intersection) / union

print(jaccard_similarity(list1, list2))
# Out:
# 0.06349206349206349

# %% [markdown]
# ## Jaccard Similarity between Diseases

# %%
import itertools
import pandas as pd

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(symptoms, disease), (symptoms, disease)]
wordings_users = list(zip(df["symptoms"], df["disease"]))

result = []

# create list of all possible combinations between sets of (symptoms, disease) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"disease1": item[0][1], "disease2": item[1][1], "similarity": similarity}
    result.append(data)

df_final = pd.DataFrame(result)
df_final = df_final.sort_values(by = 'similarity', ascending=False)
df_final.head(20)
# Out:
#                                       disease1  \
# 80187                 Dry macular degeneration
# 94167                Floor of the mouth cancer
# 114182           Immune thrombocytopenia (ITP)
# 87683                                 Epilepsy
# 124112                                Lymphoma
# 135850                             Prediabetes
# 110798  Hodgkin's lymphoma (Hodgkin's disease)
# 110837  Hodgkin's lymphoma (Hodgkin's disease)
# 60415                   Chronic kidney disease
# 41907                              Broken hand
# 103988                        Heart arrhythmia
# 65457                             Colon cancer
# 122517                        Liver hemangioma
# 122313                            Liver cancer
# 122265                            Liver cancer
# 54114                          Cervical cancer
# 136415                         Prostate cancer
# 19130                     Aortic valve disease
# 71131                          Crohn's disease
# 63023                                Cirrhosis
#
#                                      disease2  similarity
# 80187                Wet macular degeneration    1.000000
# 94167                      Soft palate cancer    0.812500
# 114182  Thrombocytopenia (low platelet count)    0.779661
# 87683                                Seizures    0.766667
# 124112                                    Non    0.750000
# 135850                        Type 2 diabetes    0.724138
# 110798                               Lymphoma    0.700000
# 110837                                    Non    0.641509
# 60415                                     End    0.633333
# 41907                            Broken wrist    0.625000
# 103988           Supraventricular tachycardia    0.513514
# 65457                           Rectal cancer    0.500000
# 122517       Nonalcoholic fatty liver disease    0.492537
# 122313       Nonalcoholic fatty liver disease    0.486842
# 122265                       Liver hemangioma    0.485294
# 54114                          Vaginal cancer    0.464286
# 136415                Stage 4 prostate cancer    0.458333
# 19130                   Aortic valve stenosis    0.419355
# 71131        Inflammatory bowel disease (IBD)    0.411765
# 63023        Nonalcoholic fatty liver disease    0.410000

# %% [markdown]
# > Comments: Some of the diseases are very similar in symptoms, for example 'floor of the mouth cancer' and 'soft palate cancer', 'colon cancer' and 'rectal cancer', 'cervical cancer and 'vaginal cancer' etc.
